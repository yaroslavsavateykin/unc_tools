# %%
from unc_tools import FunctionBase1D
from IPython.display import display, Latex

# %%
def ldisplay(expr):
    display(Latex("$" + expr + "$"))

def print_all_info(expr, ys = [0,"t",5]):
    print(f"""
Expresssion :           {expr.expr_str}
Sympy expression:       {expr.expr_sym}
All solutions expr = 0: {expr.sols}
LaTeX expression:       {expr.to_latex_expr()}
""")
    ldisplay(expr.to_latex_expr())

    for y in ys:
        print("-"*20)
        print(f"""
Solutions expr = {y}: {expr.find_sols(y)}
LaTeX solutions for expr = {y}:\n{expr.to_latex_sols()}
LaTeX solutions for expr = {y} with uncertainty:\n{expr.to_latex_sols(show_unc=True)}
""")
        ldisplay(expr.to_latex_sols(y))
        ldisplay(expr.to_latex_sols(y,show_unc=True))

# %%
expr = FunctionBase1D("a*x + b")


print_all_info(expr)
# Out:
# Expresssion :           a*x + b
# Sympy expression:       a*x + b
# All solutions expr = 0: [-b/a]
# LaTeX expression:       a x + b
# $a x + b$
# --------------------
#
# Solutions expr = 0: -b/a
# LaTeX solutions for expr = 0:
# \begin{array}{l}
# x_1 = - \frac{b}{a} \\
# \end{array}
# LaTeX solutions for expr = 0 with uncertainty:
# \begin{array}{l}
# x_1 = - \frac{b}{a} + \sqrt{\frac{\Delta_{a}^{2} b^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}}} \\
# \end{array}
# $\begin{array}{l}
# x_1 = - \frac{b}{a} \\
# \end{array}$
# $\begin{array}{l}
# x_1 = - \frac{b}{a} + \sqrt{\frac{\Delta_{a}^{2} b^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}}} \\
# \end{array}$
# --------------------
#
# Solutions expr = t: (-b + t)/a
# LaTeX solutions for expr = t:
# \begin{array}{l}
# x_1 = - \frac{b}{a} \\
# \end{array}
# LaTeX solutions for expr = t with uncertainty:
# \begin{array}{l}
# x_1 = - \frac{b}{a} + \sqrt{\frac{\Delta_{a}^{2} b^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}}} \\
# \end{array}
# $\begin{array}{l}
# x_1 = \frac{- b + t}{a} \\
# \end{array}$
# $\begin{array}{l}
# x_1 = \frac{- b + t}{a} + \sqrt{\frac{\Delta_{a}^{2} \left(- b + t\right)^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}} + \frac{\Delta_{t}^{2}}{a^{2}}} \\
# \end{array}$
# --------------------
#
# Solutions expr = 5: (5 - b)/a
# LaTeX solutions for expr = 5:
# \begin{array}{l}
# x_1 = - \frac{b}{a} \\
# \end{array}
# LaTeX solutions for expr = 5 with uncertainty:
# \begin{array}{l}
# x_1 = - \frac{b}{a} + \sqrt{\frac{\Delta_{a}^{2} b^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}}} \\
# \end{array}
# $\begin{array}{l}
# x_1 = \frac{5 - b}{a} \\
# \end{array}$
# $\begin{array}{l}
# x_1 = \frac{5 - b}{a} + \sqrt{\frac{\Delta_{a}^{2} \left(5 - b\right)^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}}} \\
# \end{array}$

# %%
expr = FunctionBase1D("a*x**2 + b + exp(x)")

print_all_info(expr)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 expr = FunctionBase1D("a*x**2 + b + exp(x)")
# ----> 3 print_all_info(expr)
#
# Cell In[2], line 8, in print_all_info(expr, ys)
#       4 def print_all_info(expr, ys = [0,"t",5]):
#       5     print(f"""
#       6 Expresssion :           {expr.expr_str}
#       7 Sympy expression:       {expr.expr_sym}
# ----> 8 All solutions expr = 0: {expr.sols}
#       9 LaTeX expression:       {expr.to_latex_expr()}
#      10 """)
#      11     ldisplay(expr.to_latex_expr())
#      13     for y in ys:
#
# File /usr/lib/python3.12/functools.py:995, in cached_property.__get__(self, instance, owner)
#     993 val = cache.get(self.attrname, _NOT_FOUND)
#     994 if val is _NOT_FOUND:
# --> 995     val = self.func(instance)
#     996     try:
#     997         cache[self.attrname] = val
#
# File ~/notebooks/venv/lib/python3.12/site-packages/unc_tools/default_functions.py:128, in FunctionBase1D.sols(self)
#     100 """Solve the expression set equal to zero.
#     101
#     102 Returns analytical solutions, optionally excluding complex values unless
#    (...)    112     Caches solutions for reuse.
#     113 """
#     114 # try:
#     115 #     solution = sym.solvers.solve(self.expr_sym - 0, sym.Symbol("x"))
#     116 #
#    (...)    126 #     return []
#     127 #
# --> 128 solution = sym.solvers.solve(self.expr_sym - 0, sym.Symbol("x"))
#     130 # if not solution:
#     131 #    raise TypeError("Cant find analytical solution for given expression")
#     133 if self._show_complex:
#
# File ~/notebooks/venv/lib/python3.12/site-packages/sympy/solvers/solvers.py:1168, in solve(f, *symbols, **flags)
#    1166         solution = _solve_undetermined(f[0], symbols, flags)
#    1167     if not solution:
# -> 1168         solution = _solve(f[0], *symbols, **flags)
#    1169 else:
#    1170     linear, solution = _solve_system(f, symbols, **flags)
#
# File ~/notebooks/venv/lib/python3.12/site-packages/sympy/solvers/solvers.py:1722, in _solve(f, *symbols, **flags)
#    1719 # ----------- end of fallback ----------------------------
#    1721 if result is False:
# -> 1722     raise NotImplementedError('\n'.join([msg, not_impl_msg % f]))
#    1724 result = _remove_duplicate_solutions(result)
#    1726 if flags.get('simplify', True):
#
# NotImplementedError: multiple generators [x, exp(x)]
# No algorithms are implemented to solve equation a*x**2 + b + exp(x)

# %%
from unc_tools import Poly

expr = Poly(3)

print_all_info(expr, ys = [0])

# %%
from unc_tools import Hyper

expr = Hyper()

print_all_info(expr)
