# %%
from unc_tools import FunctionBase1D
from IPython.display import display, Latex

# %%
def ldisplay(expr):
    display(Latex("$" + expr + "$"))

def print_all_info(expr, ys = [0,"t",5]):
    print(f"""
Expresssion :           {expr.expr_str}
Sympy expression:       {expr.expr_sym}
All solutions expr = 0: {expr.sols}
LaTeX expression:       {expr.to_latex_expr()}
""")
    ldisplay(expr.to_latex_expr())

    for y in ys:
        print("-"*20)
        print(f"""
Solutions expr = {y}: {expr.find_sols(y)}
LaTeX solutions for expr = {y}:\n{expr.to_latex_sols()}
LaTeX solutions for expr = {y} with uncertainty:\n{expr.to_latex_sols(show_unc=True)}
""")
        ldisplay(expr.to_latex_sols(y))
        ldisplay(expr.to_latex_sols(y,show_unc=True))

# %%
expr = FunctionBase1D("a*x + b")


print_all_info(expr)
# Out:
# Expresssion :           a*x + b
# Sympy expression:       a*x + b
# All solutions expr = 0: [-b/a]
# LaTeX expression:       a x + b
# $a x + b$
# --------------------
#
# Solutions expr = 0: -b/a
# LaTeX solutions for expr = 0:
# \begin{array}{l}
# x_1 = - \frac{b}{a} \\
# \end{array}
# LaTeX solutions for expr = 0 with uncertainty:
# \begin{array}{l}
# x_1 = - \frac{b}{a} + \sqrt{\frac{\Delta_{a}^{2} b^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}}} \\
# \end{array}
# $\begin{array}{l}
# x_1 = - \frac{b}{a} \\
# \end{array}$
# $\begin{array}{l}
# x_1 = - \frac{b}{a} + \sqrt{\frac{\Delta_{a}^{2} b^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}}} \\
# \end{array}$
# --------------------
#
# Solutions expr = t: (-b + t)/a
# LaTeX solutions for expr = t:
# \begin{array}{l}
# x_1 = - \frac{b}{a} \\
# \end{array}
# LaTeX solutions for expr = t with uncertainty:
# \begin{array}{l}
# x_1 = - \frac{b}{a} + \sqrt{\frac{\Delta_{a}^{2} b^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}}} \\
# \end{array}
# $\begin{array}{l}
# x_1 = \frac{- b + t}{a} \\
# \end{array}$
# $\begin{array}{l}
# x_1 = \frac{- b + t}{a} + \sqrt{\frac{\Delta_{a}^{2} \left(- b + t\right)^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}} + \frac{\Delta_{t}^{2}}{a^{2}}} \\
# \end{array}$
# --------------------
#
# Solutions expr = 5: (5 - b)/a
# LaTeX solutions for expr = 5:
# \begin{array}{l}
# x_1 = - \frac{b}{a} \\
# \end{array}
# LaTeX solutions for expr = 5 with uncertainty:
# \begin{array}{l}
# x_1 = - \frac{b}{a} + \sqrt{\frac{\Delta_{a}^{2} b^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}}} \\
# \end{array}
# $\begin{array}{l}
# x_1 = \frac{5 - b}{a} \\
# \end{array}$
# $\begin{array}{l}
# x_1 = \frac{5 - b}{a} + \sqrt{\frac{\Delta_{a}^{2} \left(5 - b\right)^{2}}{a^{4}} + \frac{\Delta_{b}^{2}}{a^{2}}} \\
# \end{array}$

# %%
expr = FunctionBase1D("a*x**2 + b + exp(x)")

print_all_info(expr)
# Out:
# Expresssion :           a*x**2 + b + exp(x)
# Sympy expression:       a*x**2 + b + exp(x)
# All solutions expr = 0: []
# LaTeX expression:       a x^{2} + b + e^{x}
# $a x^{2} + b + e^{x}$
# --------------------
#
# Solutions expr = 0: []
# LaTeX solutions for expr = 0:
# \begin{array}{l}
#
# \end{array}
# LaTeX solutions for expr = 0 with uncertainty:
# \begin{array}{l}
#
# \end{array}
# $\begin{array}{l}
#
# \end{array}$
# $\begin{array}{l}
#
# \end{array}$
# --------------------
#
# Solutions expr = t: []
# LaTeX solutions for expr = t:
# \begin{array}{l}
#
# \end{array}
# LaTeX solutions for expr = t with uncertainty:
# \begin{array}{l}
#
# \end{array}
# $\begin{array}{l}
#
# \end{array}$
# $\begin{array}{l}
#
# \end{array}$
# --------------------
#
# Solutions expr = 5: []
# LaTeX solutions for expr = 5:
# \begin{array}{l}
#
# \end{array}
# LaTeX solutions for expr = 5 with uncertainty:
# \begin{array}{l}
#
# \end{array}
# $\begin{array}{l}
#
# \end{array}$
# $\begin{array}{l}
#
# \end{array}$

# %%
from unc_tools import Poly

expr = Poly(3)

print_all_info(expr, ys = [0])
# Out:
# Expresssion :           p_0*x**3 + p_1*x**2 + p_2*x**1 + p_3
# Sympy expression:       p_0*x**3 + p_1*x**2 + p_2*x + p_3
# All solutions expr = 0: [-(-3*p_2/p_0 + p_1**2/p_0**2)/(3*(sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)) - (sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)/3 - p_1/(3*p_0), -(-3*p_2/p_0 + p_1**2/p_0**2)/(3*(-1/2 - sqrt(3)*I/2)*(sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)/3 - p_1/(3*p_0), -(-3*p_2/p_0 + p_1**2/p_0**2)/(3*(-1/2 + sqrt(3)*I/2)*(sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)) - (-1/2 + sqrt(3)*I/2)*(sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)/3 - p_1/(3*p_0)]
# LaTeX expression:       p_{0} x^{3} + p_{1} x^{2} + p_{2} x + p_{3}
# $p_{0} x^{3} + p_{1} x^{2} + p_{2} x + p_{3}$
# --------------------
#
# Solutions expr = 0: [-(-3*p_2/p_0 + p_1**2/p_0**2)/(3*(sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)) - (sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)/3 - p_1/(3*p_0), -(-3*p_2/p_0 + p_1**2/p_0**2)/(3*(-1/2 - sqrt(3)*I/2)*(sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)/3 - p_1/(3*p_0), -(-3*p_2/p_0 + p_1**2/p_0**2)/(3*(-1/2 + sqrt(3)*I/2)*(sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)) - (-1/2 + sqrt(3)*I/2)*(sqrt(-4*(-3*p_2/p_0 + p_1**2/p_0**2)**3 + (27*p_3/p_0 - 9*p_1*p_2/p_0**2 + 2*p_1**3/p_0**3)**2)/2 + 27*p_3/(2*p_0) - 9*p_1*p_2/(2*p_0**2) + p_1**3/p_0**3)**(1/3)/3 - p_1/(3*p_0)]
# LaTeX solutions for expr = 0:
# \begin{array}{l}
# x_1 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} \\
# x_2 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} \\
# x_3 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} \\
# \end{array}
# LaTeX solutions for expr = 0 with uncertainty:
# \begin{array}{l}
# x_1 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} + \sqrt{\Delta_{p 0}^{2} \left(- \frac{\frac{3 p_{2}}{p_{0}^{2}} - \frac{2 p_{1}^{2}}{p_{0}^{3}}}{3 \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} + \frac{9 p_{3}}{2 p_{0}^{2}} - \frac{3 p_{1} p_{2}}{p_{0}^{3}} + \frac{p_{1}^{3}}{p_{0}^{4}}\right)}{3 \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{4}{3}}} - \frac{\frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} - \frac{9 p_{3}}{2 p_{0}^{2}} + \frac{3 p_{1} p_{2}}{p_{0}^{3}} - \frac{p_{1}^{3}}{p_{0}^{4}}}{3 \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{2}{3}}} + \frac{p_{1}}{3 p_{0}^{2}}\right)^{2} + \Delta_{p 1}^{2} \left(- \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{\frac{\left(- \frac{18 p_{2}}{p_{0}^{2}} + \frac{12 p_{1}^{2}}{p_{0}^{3}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2} - \frac{12 p_{1} \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2}}{p_{0}^{2}}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} + \frac{3 p_{2}}{2 p_{0}^{2}} - \frac{p_{1}^{2}}{p_{0}^{3}}\right)}{3 \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\fr ...
# x_2 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} + \sqrt{\Delta_{p 0}^{2} \left(- \frac{\frac{3 p_{2}}{p_{0}^{2}} - \frac{2 p_{1}^{2}}{p_{0}^{3}}}{3 \left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} + \frac{9 p_{3}}{2 p_{0}^{2}} - \frac{3 p_{1} p_{2}}{p_{0}^{3}} + \frac{p_{1}^{3}}{p_{0}^{4}}\right)}{3 \left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{4}{3}}} - \frac{\left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \left(\frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} - \frac{9 p_{3}}{2 p_{0}^{2}} + \frac{3 p_{1} p_{2}}{p_{0}^{3}} - \frac{p_{1}^{3}}{p_{0}^{4}}\right)}{3 \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{2}{3}}} + \frac{p_{1}}{3 p_{0}^{2}}\right)^{2} + \Delta_{p 1}^{2} \left(- \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{\frac{\left(- \frac{18 p_{2}}{p_{0}^{2}} + \frac{12 p_{1}^{2}}{p_{0}^{3}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2} - \frac{12 p_{1} \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2}}{p_{0}^{2}}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3 ...
# x_3 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} + \sqrt{\Delta_{p 0}^{2} \left(- \frac{\frac{3 p_{2}}{p_{0}^{2}} - \frac{2 p_{1}^{2}}{p_{0}^{3}}}{3 \left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} + \frac{9 p_{3}}{2 p_{0}^{2}} - \frac{3 p_{1} p_{2}}{p_{0}^{3}} + \frac{p_{1}^{3}}{p_{0}^{4}}\right)}{3 \left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{4}{3}}} - \frac{\left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \left(\frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} - \frac{9 p_{3}}{2 p_{0}^{2}} + \frac{3 p_{1} p_{2}}{p_{0}^{3}} - \frac{p_{1}^{3}}{p_{0}^{4}}\right)}{3 \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{2}{3}}} + \frac{p_{1}}{3 p_{0}^{2}}\right)^{2} + \Delta_{p 1}^{2} \left(- \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{\frac{\left(- \frac{18 p_{2}}{p_{0}^{2}} + \frac{12 p_{1}^{2}}{p_{0}^{3}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2} - \frac{12 p_{1} \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2}}{p_{0}^{2}}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3 ...
# \end{array}
# $\begin{array}{l}
# x_1 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} \\
# x_2 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} \\
# x_3 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} \\
# \end{array}$
# $\begin{array}{l}
# x_1 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} + \sqrt{\Delta_{p 0}^{2} \left(- \frac{\frac{3 p_{2}}{p_{0}^{2}} - \frac{2 p_{1}^{2}}{p_{0}^{3}}}{3 \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} + \frac{9 p_{3}}{2 p_{0}^{2}} - \frac{3 p_{1} p_{2}}{p_{0}^{3}} + \frac{p_{1}^{3}}{p_{0}^{4}}\right)}{3 \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{4}{3}}} - \frac{\frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} - \frac{9 p_{3}}{2 p_{0}^{2}} + \frac{3 p_{1} p_{2}}{p_{0}^{3}} - \frac{p_{1}^{3}}{p_{0}^{4}}}{3 \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{2}{3}}} + \frac{p_{1}}{3 p_{0}^{2}}\right)^{2} + \Delta_{p 1}^{2} \left(- \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{\frac{\left(- \frac{18 p_{2}}{p_{0}^{2}} + \frac{12 p_{1}^{2}}{p_{0}^{3}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2} - \frac{12 p_{1} \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2}}{p_{0}^{2}}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} + \frac{3 p_{2}}{2 p_{0}^{2}} - \frac{p_{1}^{2}}{p_{0}^{3}}\right)}{3 \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\fr ...
# x_2 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} + \sqrt{\Delta_{p 0}^{2} \left(- \frac{\frac{3 p_{2}}{p_{0}^{2}} - \frac{2 p_{1}^{2}}{p_{0}^{3}}}{3 \left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} + \frac{9 p_{3}}{2 p_{0}^{2}} - \frac{3 p_{1} p_{2}}{p_{0}^{3}} + \frac{p_{1}^{3}}{p_{0}^{4}}\right)}{3 \left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{4}{3}}} - \frac{\left(- \frac{1}{2} - \frac{\sqrt{3} i}{2}\right) \left(\frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} - \frac{9 p_{3}}{2 p_{0}^{2}} + \frac{3 p_{1} p_{2}}{p_{0}^{3}} - \frac{p_{1}^{3}}{p_{0}^{4}}\right)}{3 \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{2}{3}}} + \frac{p_{1}}{3 p_{0}^{2}}\right)^{2} + \Delta_{p 1}^{2} \left(- \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{\frac{\left(- \frac{18 p_{2}}{p_{0}^{2}} + \frac{12 p_{1}^{2}}{p_{0}^{3}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2} - \frac{12 p_{1} \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2}}{p_{0}^{2}}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3 ...
# x_3 = - \frac{- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}}{3 \left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}}{3} - \frac{p_{1}}{3 p_{0}} + \sqrt{\Delta_{p 0}^{2} \left(- \frac{\frac{3 p_{2}}{p_{0}^{2}} - \frac{2 p_{1}^{2}}{p_{0}^{3}}}{3 \left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \sqrt[3]{\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}}} - \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} + \frac{9 p_{3}}{2 p_{0}^{2}} - \frac{3 p_{1} p_{2}}{p_{0}^{3}} + \frac{p_{1}^{3}}{p_{0}^{4}}\right)}{3 \left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{4}{3}}} - \frac{\left(- \frac{1}{2} + \frac{\sqrt{3} i}{2}\right) \left(\frac{- 2 \left(\frac{9 p_{2}}{p_{0}^{2}} - \frac{6 p_{1}^{2}}{p_{0}^{3}}\right) \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2} + \frac{\left(- \frac{54 p_{3}}{p_{0}^{2}} + \frac{36 p_{1} p_{2}}{p_{0}^{3}} - \frac{12 p_{1}^{3}}{p_{0}^{4}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}} - \frac{9 p_{3}}{2 p_{0}^{2}} + \frac{3 p_{1} p_{2}}{p_{0}^{3}} - \frac{p_{1}^{3}}{p_{0}^{4}}\right)}{3 \left(\frac{\sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)^{2}}}{2} + \frac{27 p_{3}}{2 p_{0}} - \frac{9 p_{1} p_{2}}{2 p_{0}^{2}} + \frac{p_{1}^{3}}{p_{0}^{3}}\right)^{\frac{2}{3}}} + \frac{p_{1}}{3 p_{0}^{2}}\right)^{2} + \Delta_{p 1}^{2} \left(- \frac{\left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right) \left(- \frac{\frac{\left(- \frac{18 p_{2}}{p_{0}^{2}} + \frac{12 p_{1}^{2}}{p_{0}^{3}}\right) \left(\frac{27 p_{3}}{p_{0}} - \frac{9 p_{1} p_{2}}{p_{0}^{2}} + \frac{2 p_{1}^{3}}{p_{0}^{3}}\right)}{2} - \frac{12 p_{1} \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{2}}{p_{0}^{2}}}{6 \sqrt{- 4 \left(- \frac{3 p_{2}}{p_{0}} + \frac{p_{1}^{2}}{p_{0}^{2}}\right)^{3} + \left(\frac{27 p_{3 ...
# \end{array}$

# %%
from unc_tools import Hyper

expr = Hyper()

print_all_info(expr)
# Out:
# Expresssion :           p_0*x / (x + p_1)
# Sympy expression:       p_0*x/(p_1 + x)
# All solutions expr = 0: [0]
# LaTeX expression:       \frac{p_{0} x}{p_{1} + x}
# $\frac{p_{0} x}{p_{1} + x}$
# --------------------
#
# Solutions expr = 0: 0
# LaTeX solutions for expr = 0:
# \begin{array}{l}
# x_1 = 0 \\
# \end{array}
# LaTeX solutions for expr = 0 with uncertainty:
# \begin{array}{l}
# x_1 = 0 + 0.0 \\
# \end{array}
# $\begin{array}{l}
# x_1 = 0 \\
# \end{array}$
# $\begin{array}{l}
# x_1 = 0 + 0.0 \\
# \end{array}$
# --------------------
#
# Solutions expr = t: p_1*t/(p_0 - t)
# LaTeX solutions for expr = t:
# \begin{array}{l}
# x_1 = 0 \\
# \end{array}
# LaTeX solutions for expr = t with uncertainty:
# \begin{array}{l}
# x_1 = 0 + 0.0 \\
# \end{array}
# $\begin{array}{l}
# x_1 = \frac{p_{1} t}{p_{0} - t} \\
# \end{array}$
# $\begin{array}{l}
# x_1 = \frac{p_{1} t}{p_{0} - t} + \sqrt{\frac{\Delta_{p 0}^{2} p_{1}^{2} t^{2}}{\left(p_{0} - t\right)^{4}} + \frac{\Delta_{p 1}^{2} t^{2}}{\left(p_{0} - t\right)^{2}} + \Delta_{t}^{2} \left(\frac{p_{1} t}{\left(p_{0} - t\right)^{2}} + \frac{p_{1}}{p_{0} - t}\right)^{2}} \\
# \end{array}$
# --------------------
#
# Solutions expr = 5: 5*p_1/(p_0 - 5)
# LaTeX solutions for expr = 5:
# \begin{array}{l}
# x_1 = 0 \\
# \end{array}
# LaTeX solutions for expr = 5 with uncertainty:
# \begin{array}{l}
# x_1 = 0 + 0.0 \\
# \end{array}
# $\begin{array}{l}
# x_1 = \frac{5 p_{1}}{p_{0} - 5} \\
# \end{array}$
# $\begin{array}{l}
# x_1 = \frac{5 p_{1}}{p_{0} - 5} + \sqrt{\frac{25 \Delta_{p 0}^{2} p_{1}^{2}}{\left(p_{0} - 5\right)^{4}} + \frac{25 \Delta_{p 1}^{2}}{\left(p_{0} - 5\right)^{2}}} \\
# \end{array}$
