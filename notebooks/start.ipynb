# %% [markdown]
# # Welcome to uncertainty-tools notebooks
#
# This notebook clones the full repository so you have access to all examples.
#
# Open the notebooks in:
# `unc_tools/notebooks/`
#
# Recommended order:
# 1. 1 - Function1Based
# 2. 2 - UncRegression
# 3. 3 - Examples

# %%
# Clone the repository
# !git clone https://github.com/yaroslavsavateykin/unc_tools.git

# (optional) install the package
# !pip install uncertainty-tools
